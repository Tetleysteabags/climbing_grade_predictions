# %%
# import csv files
import csv
import os
import sys
import pandas as pd
import numpy as np

# %%
df_boulder = pd.read_csv('data_filtered_bouldering_new.csv')
df_sport = pd.read_csv('data_filtered_sport_new.csv')

# %%
# show the max and min of the boulder and sport grades dfs

print(df_boulder['max_boulder_numeric'].max())
print(df_boulder['max_boulder_numeric'].min())

print(df_sport['max_sport_numeric'].max())
print(df_sport['max_sport_numeric'].min())
# Out:
# 14.0
# 0.0
# 22.0
# 0.0

# %%
# show the distribution of grades in the boulder and sport dfs
df_boulder['max_boulder_numeric'].hist()
# Out:
# <Axes: >

# %%
df_sport['max_sport_numeric'].hist()
# Out:
# <Axes: >

# %%
# filter the bouldering and sport dfs to only show the grades that are in the top 10% of the distribution
df_boulder_top_10 = df_boulder[df_boulder['max_boulder_numeric'] > 8]
df_sport_top_10 = df_sport[df_sport['max_sport_numeric'] > 15]

# %%
# Keep only the columns that are needed
df_boulder_top_10 = df_boulder_top_10[['age', 'max_boulder_numeric', 'exp', 'height','weight','pullup','continuous','maxhang','weightedpull','repeaters1']]
# Keep only those which do not have NaN values
df_boulder_top_10 = df_boulder_top_10.dropna()
df_boulder_top_10
# Out:
#       age  max_boulder_numeric  exp   height     weight  pullup  continuous  \
# 8    31.0                 11.0  6.0  181.610  74.842741    18.0        65.0
# 17   37.0                  9.0  7.0  175.260  67.131671    13.0        50.0
# 26   32.0                 14.0  7.0  177.800  70.306817    16.0        67.0
# 27   38.0                  9.0  7.0  157.480  54.431084    12.0        40.0
# 29   27.0                  9.0  6.0  170.180  61.234970    15.0        45.0
# ..    ...                  ...  ...      ...        ...     ...         ...
# 461  41.0                  9.0  7.0  175.260  68.038855    17.0        51.0
# 470  36.0                 11.0  6.0  165.100  47.627199    14.0        48.0
# 472  29.0                  9.0  4.0  193.040  92.986436    12.0        22.0
# 476  25.0                  9.0  5.0  185.420  77.110703    33.0        60.4
# 480  25.0                 12.0  7.0  179.832  66.678078    14.0        66.0
#
#        maxhang  weightedpull  repeaters1
# ...

# %%
# show distribution for each column
df_boulder_top_10['max_boulder_numeric'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['exp'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['pullup'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['continuous'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['maxhang'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['weightedpull'].hist()
# Out:
# <Axes: >

# %%
df_boulder_top_10['repeaters1'].hist()
# Out:
# <Axes: >
